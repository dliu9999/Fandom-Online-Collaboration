# %%
import wikipedia
import pandas as pd
import numpy as np
import os
import re
from bs4 import BeautifulSoup
from pywikibot import Site, User
import requests

# %%
#given a username, find all their contributions

def find_contributions(user):
    '''
    Given a username, 
    find all their contributions on Wikipedia
    '''
    site = Site('en', 'wikipedia')  # The site we want to run our bot on
    user = User(site, user)

    contrib = []
    for page, oldid, ts, comment in user.contributions():
        # for each edit, yields (pywikibot.Page, oldid, pywikibot.Timestamp, comment)
        contrib.append(page.title() + " ^^^ " + comment)
        
    return contrib

# %%
user = 'Danbloch'
len(find_contributions(user))
# Out:
# 500

# %%
def find_users(fp, article_name):
    '''
    Given a light dump file and an article name, 
    find unique list of users who contributed
    '''

    #find usernames from ld
    with open(fp) as f:
        content = f.readlines()

    users = {}

    for line in content:
        line = line.strip()

        if line[:4] != "^^^_":  # line is title
            title = line
            users[title] = []
        else:  # line is revision
            users[title].append(line.split(" ")[3])        

    lst = users[article_name]
    return [i for n, i in enumerate(lst) if i not in lst[:n]] 
#     return users[article_name]

# %%
fp = "../data/raw/light_dump/Kpop_ld.txt"
find_users(fp, "BTS")
# Out:
# ['Hinorisakamachi',
#  '39.198.179.240',
#  'FrescoBot',
#  'Melonkelon',
#  '99.236.74.160',
#  '112.208.67.181',
#  '31.22.98.132',
#  '61.4.77.89',
#  '217.118.64.55',
#  '122.3.141.104',
#  '178.149.154.220',
#  '86.152.144.157',
#  'DiaClass',
#  '72.179.180.171',
#  '174.113.19.57',
#  '206.248.163.65',
#  '2602:306:CF4D:AE20:6C52:E105:AAE6:3300',
#  'Jiminswife',
#  '65.75.85.52',
#  '76.103.174.142',
#  'Dr.K.',
#  'Tsirip',
#  '60.48.108.60',
#  '175.140.141.26',
#  'T1r510',
#  'XLinkBot',
#  'Dianatran2828',
#  'Ishaarontrinh',
#  '84.135.92.88',
#  '187.14.15.211',
#  '99.120.227.246',
#  '98.219.107.37',
#  '76.93.136.241',
#  'Lowwerhigherguy8754',
#  '219.74.29.181',
#  '38.121.245.98',
#  '166.48.168.221',
#  '112.205.218.188',
#  '88.187.120.159',
#  '151.231.106.187',
#  '75.128.55.71',
#  'Shidomi',
#  '175.38.207.106',
#  '84.94.187.39',
#  'Kmjnmyn',
#  '68.7.82.97',
#  '24.79.164.203',
#  '69.140.163.147',
#  '173.178.203.54',
#  '84.135.92.4',
#  'Bangtan',
#  '216.58.78.42',
#  'PotatoeBacon',
#  '207.210.56.212',
#  'Evanswag22',
#  'Kanghuitari',
#  'AvicBot',
#  '37.208.145.227',
#  'Widr',
#  'Ryokucha378',
#  '62.198.45.190',
#  'Shaun',
#  '24.115.64.30',
#  '137.147.30.12',
#  'ClueBot',
#  '99.116.224.228',
#  '187.22.130.97',
#  '85.26.232.230',
#  '176.251.81.252',
#  '177.99.119.152',
#  '117.213.145.149',
#  '177.159.91.202',
#  'Jaysonman2041',
#  '99.42.13.148',
#  '110.139.173.24',
#  '125.212.123.118',
#  'Titodutta',
#  '173.18.89.173',
#  '36.81.101.172',
#  'BlueEyesX3',
#  '82.41.161.245',
#  'Evaders99',
#  '14.207.142.132',
#  '213.57.242.210',
#  '112.200.178.181',
#  'Rumrumrumpumdf',
#  '175.141.212.15',
#  'Mundo1234555',
#  '69.250.94.83',
#  '177.158.67.157',
#  '175.142.137.211',
#  '180.250.126.246',
#  '125.160.40.200',
#  '46.115.124.79',
#  '70.79.101.1',
#  'RAEHYUNG',
#  '177.157.132.201',
#  '112.198.82.122',
#  '180.243.213.197',
#  '103.10.67.66',
#  '180.194.251.73',
#  '76.103.179.52',
#  '50.133.24.146',
#  'Frederickjames000',
#  '125.166.235.109',
#  '115.134.157.33',
#  'Ozzydizzy721',
#  'Chyoobi',
#  'Vollumed',
#  '186.207.145.152',
#  '123.3.188.149',
#  '177.205.191.127',
#  '173.72.136.26',
#  '115.132.82.226',
#  '4-way1ronner',
#  'Mark',
#  'Tsuk1n3k0',
#  'Quantumleappad',
#  'Tiemianwusi',
#  'Ruby',
#  'Bamyers99',
#  'RafaelPPascual',
#  'Mogism',
#  'Apettyfer',
#  'Masymenos',
#  'PhnomPencil',
#  'DumbBOT',
#  '217.120.143.133',
#  '209.55.103.31',
#  '184.17.199.26',
#  '184.56.97.60',
#  '2601:C:9100:47B:A9AD:7A58:4A95:F5AF',
#  'Nushtella',
#  'BG19bot',
#  'Ryderong',
#  '188.55.173.239',
#  '86.146.137.228',
#  '재즈리',
#  '2A02:2028:17A:88D1:4DCC:9ED3:2369:24DD',
#  '112.215.36.145',
#  'Discospinster',
#  'Btsjjk',
#  '31.46.52.240',
#  'Adenlee834',
#  '184.17.194.174',
#  '50.143.82.168',
#  '200.216.43.78',
#  '86.34.239.132',
#  '24.254.213.17',
#  'Puramyun31',
#  '103.23.135.151',
#  '135.0.101.60',
#  'I',
#  '98.234.152.164',
#  'Gitawing',
#  'Ashleyamelia',
#  '124.6.181.204',
#  '99.192.113.192',
#  'Elfbabyarmymelody',
#  '112.198.64.92',
#  '98.244.179.208',
#  'Walter',
#  '189.76.24.10',
#  '76.168.59.62',
#  '112.198.77.116',
#  '41.223.140.24',
#  '99.126.117.105',
#  'Iam',
#  '189.76.31.69',
#  '182.4.181.235',
#  '68.224.235.127',
#  '182.218.68.23',
#  'Rizaroi',
#  '114.79.29.209',
#  'Della910708',
#  '90.215.213.206',
#  '124.149.85.29',
#  '120.28.133.207',
#  '74.138.172.133',
#  '114.199.125.194',
#  'GoingBatty',
#  'Ggbfbgfbgfbf',
#  'HueSatLum',
#  '24.34.124.155',
#  '180.73.213.27',
#  'N/A',
#  'Metal',
#  'Potatoes551',
#  'Yuriko122',
#  '112.205.22.239',
#  '222.124.217.166',
#  '90.200.137.169',
#  '186.229.90.132',
#  'Carsonquan52',
#  '125.212.120.161',
#  '90.230.32.202',
#  '36.85.222.95',
#  '107.184.28.186',
#  '2.219.157.16',
#  '112.207.19.171',
#  '191.185.82.221',
#  'Tombus20032000',
#  'Lonelywatermelone',
#  '174.98.115.220',
#  '118.137.217.78',
#  'Redrose64',
#  'RalphHyo',
#  '2602:301:77DF:7250:FD7A:E293:8BBB:199',
#  '179.253.43.91',
#  'Amortias',
#  '49.145.221.183',
#  '107.203.98.4',
#  '83.26.23.224',
#  'Teemeah',
#  '222.127.85.119',
#  'Vemodighet',
#  'Exosehun111',
#  '120.28.196.133',
#  'KimJongHee',
#  '83.26.28.197',
#  '5.65.120.205',
#  '121.100.98.40',
#  '70.116.108.137',
#  'Bollyjeff',
#  'BTS',
#  'Bangtanboys',
#  'Lemony34',
#  '180.190.194.211',
#  '50.178.233.169',
#  '112.208.172.199',
#  'Yobot',
#  'Nymks',
#  '84.236.104.89',
#  '120.168.0.69',
#  '49.145.36.78',
#  '124.6.181.76',
#  '99.122.170.55',
#  'Arjayay',
#  '2606:6000:E581:7300:B091:F83C:EB77:34F6',
#  '84.54.176.131',
#  '83.26.32.3',
#  '38.78.128.35',
#  '46.50.35.46',
#  'Magioladitis',
#  '112.198.77.17',
#  'Tmblrellesuger',
#  '199.119.128.206',
#  '62.31.93.109',
#  '121.54.47.51',
#  '172.2.116.17',
#  '2601:4:1D80:581:8135:9288:9762:589D',
#  'Pompommars',
#  'Pompomma',
#  'Denniss',
#  '203.215.118.12',
#  '112.211.183.185',
#  '58.10.212.163',
#  '2.24.133.251',
#  '2.230.170.213',
#  '99.230.138.86',
#  'BloodDoll',
#  '24.52.210.242',
#  'Bangtanbap',
#  '94.1.177.230',
#  '49.144.133.254',
#  '79.112.122.34',
#  '112.200.2.62',
#  '84.38.209.77',
#  '79.239.65.146',
#  '2601:A:4E00:40F:4C17:D18C:A3FB:5F96',
#  '74.78.248.25',
#  'Megmars',
#  '179.178.30.249',
#  '66.116.0.154',
#  'Pockyixing',
#  '188.27.95.247',
#  '173.180.248.12',
#  'Pompommam',
#  'Kinu',
#  '63.231.210.41',
#  '198.137.20.70',
#  '108.89.17.94',
#  'MinJaeseumin',
#  'Sugamonster',
#  'Jc3700',
#  '179.98.115.80',
#  '173.2.150.209',
#  '86.158.224.102',
#  '184.17.197.65',
#  '120.28.125.235',
#  '2A02:214B:8208:3F00:447F:1CF2:8693:DB6C',
#  '78.62.23.79',
#  '200.155.118.13',
#  '174.26.94.55',
#  '2601:D:3400:A1F:90C5:EFBD:EC1B:82C0',
#  'Tibbydibby',
#  '72.182.1.161',
#  '180.191.147.33',
#  '49.150.64.145',
#  'Kpopperjagger',
#  '95.93.196.122',
#  '121.96.28.150',
#  'K6ka',
#  'ICloudFapster',
#  '189.62.50.199',
#  'KH-1',
#  '202.71.185.84',
#  'Deoma12',
#  '83.26.32.128',
#  '177.134.66.2',
#  'Bangtansonyundan',
#  '189.76.19.160',
#  '187.114.237.91',
#  'Jedi94',
#  '67.232.36.91',
#  '120.161.1.175',
#  'Lennylim652',
#  '112.198.79.98',
#  'TheKpopWorldIsMyStyle14',
#  '2602:306:CF9B:E1A0:B120:29CF:9278:5103',
#  'Getbackhyun',
#  '207.30.91.32',
#  'Omghansoo',
#  'Joyceting',
#  'Hoseokbooty',
#  '71.89.65.127',
#  '99.64.240.60',
#  '173.70.63.157',
#  '110.5.67.138',
#  '98.88.134.66',
#  '83.26.28.202',
#  '195.174.36.182',
#  '82.26.153.218',
#  '2605:A000:C2C4:4F00:B9CE:5E1C:69DB:61A7',
#  '83.26.28.98',
#  'MyLoveForKPOP',
#  'Meters',
#  'AGSworld',
#  'Itsschloee',
#  'Majesticness',
#  '98.207.163.120',
#  '83.26.31.145',
#  'Famitsudc',
#  '95.232.52.10',
#  '83.251.181.155',
#  'Eyesnore',
#  '202.156.136.106',
#  '121.54.41.178',
#  'Anonpersonality',
#  '162.226.151.0',
#  '2602:306:CCD1:52D0:1172:D29D:EB97:4CCD',
#  '85.241.205.203',
#  '74.180.171.234',
#  '108.18.19.56',
#  '130.193.158.111',
#  '198.200.72.178',
#  'Kittybabylove',
#  'Onel5969',
#  '90.198.161.38',
#  '104.56.228.190',
#  'Kookiekim',
#  '92.2.77.53',
#  '222.127.174.113',
#  '83.26.31.154',
#  'AlyciaJose11111',
#  'Icecreamloverx3',
#  'Bubbleclaire',
#  'Sasquatch',
#  'Luludeer',
#  'NicoleUnnehBEBE',
#  '80.98.87.58',
#  'MusikAnimal',
#  'Friedheroine',
#  '177.141.106.250',
#  '83.26.27.71',
#  'PrkJmn',
#  'Mcmatter',
#  '222.127.174.207',
#  '91.222.148.3',
#  'Min',
#  '2602:306:34AA:CB00:74B9:1D63:E284:3DA7',
#  '125.167.141.131',
#  '79.46.94.166',
#  '83.26.24.99',
#  '112.206.14.200',
#  '79.185.25.233',
#  '124.105.173.18',
#  'Keaclamviectot',
#  'Thek00kieman',
#  '36.68.25.52',
#  'Ploylychan',
#  '73.169.178.102',
#  'Kookie7',
#  '112.198.82.34',
#  'M01x3',
#  '123.243.123.34',
#  'LittleMissRich',
#  '24.24.147.0',
#  '83.26.29.118',
#  'Blah',
#  'Frosty',
#  '99.165.37.64',
#  '83.26.24.157',
#  '71.224.211.240',
#  'BigHitEnt',
#  '83.26.27.193',
#  'Ynollia',
#  '36.75.47.78',
#  'Zuzulovesfood',
#  '66.108.181.216',
#  'Starcheerspeaksnewslostwars',
#  'Htruc',
#  '188.27.95.73',
#  '109.60.76.239',
#  'Sfan00',
#  '83.26.31.128',
#  '188.167.213.214',
#  'BD2412',
#  '184.149.27.5',
#  'M3gstarrrr',
#  'Hdjsbdkd',
#  'WadeSimMiser',
#  'Meggystarr',
#  'Kambinglha',
#  'Mean',
#  '2602:304:AEC1:DD69:7947:BCD1:88F3:2011',
#  'Ratchetluhan',
#  'Rrburke',
#  'Winner',
#  'Chaesong',
#  '218.250.90.151',
#  'Monkbot',
#  'Hoobernoob',
#  '64.92.27.24',
#  'Krros',
#  '188.2.114.140',
#  '115.66.10.246',
#  'AmyyVengeance',
#  '130.204.128.223',
#  '77.21.170.46',
#  'Ggffmnvf',
#  'Squinge',
#  'SDVUBSIBVIB',
#  '2601:8:9700:70E:7D39:4AD2:E0C1:24B',
#  'M3ggystarry',
#  '88.192.58.186',
#  '173.244.12.192',
#  '70.112.115.20',
#  '92.205.94.77',
#  '80.137.20.67',
#  '60.225.94.15',
#  'Bossanoven',
#  '202.160.36.74',
#  '83.26.25.219',
#  'CambridgeBayWeather',
#  'Random86',
#  '183.171.166.236',
#  'Taehyngs',
#  'Minangie',
#  '217.121.214.86',
#  '202.21.117.138',
#  '151.224.155.228',
#  'Exoverdosed012',
#  '2A02:1810:C009:C100:4171:583D:9EB2:6312',
#  'Exobts',
#  '107.208.14.232',
#  '112.208.87.195',
#  '112.209.233.201',
#  '210.49.68.249',
#  '202.160.35.160',
#  '208.88.253.30',
#  '27.72.80.114',
#  '212.183.127.253',
#  '98.30.62.252',
#  '95.68.199.82',
#  '108.14.13.63',
#  '121.54.44.89',
#  '114.142.218.249',
#  '112.208.252.186',
#  '42.241.158.96',
#  '175.137.69.181',
#  'Kpoplover12345',
#  '92.19.48.162',
#  'Helpsome',
#  '98.150.216.241',
#  '220.76.107.26',
#  '121.6.37.231',
#  '49.144.223.122',
#  'Exo-l']

# %%
users = find_users(fp, "BTS")
'N/A' in users
# Out:
# True

# %%
def user_contributions(fp, article_name):
    users = find_users(fp, article_name)
    contributions = {}
    for user in users:
        try:
            contributions[user] = find_contributions(user)
        except:
            continue
    return contributions

# %%
data = user_contributions(fp, "BTS")
# Out:
# WARNING: API error baduser: Invalid value "N/A" for user parameter "ucuser".

# %%
def build_df(data):
    '''
    Given user contribution data, build a user contibution dataframe
    '''
    d = []
    user = data.keys()
    for user in data.keys():
        total_contrib = len(data[user])
        for page in data[user]:
            # clean page title
            page = str(re.findall('^[^\^^^]+', page)[0][:-1])
            d.append([user, total_contrib, page])
            
    df = pd.DataFrame(d, columns = ['users', 'total_edits', 'article_name'])
    return df

# %%
df = build_df(data)
print(df.shape)
df.head()
# Out:
# (37617, 3)
#              users  total_edits             article_name
# 0  Hinorisakamachi          500           Draft:P Nation
# 1  Hinorisakamachi          500  Asian Television Awards
# 2  Hinorisakamachi          500  Asian Television Awards
# 3  Hinorisakamachi          500  Asian Television Awards
# 4  Hinorisakamachi          500  Asian Television Awards

# %%
u = df[df.users == 'Hinorisakamachi'].groupby(['users', 'article_name']).count()
tmp = u.sort_values(by='total_edits', ascending = False)
tmp
# Out:
#                                            total_edits
# users           article_name
# Hinorisakamachi Speed (South Korean band)           31
#                 Asian Television Awards             15
#                 BTS                                 14
#                 Gene Shinozaki                      14
#                 Draft:Bigman (beatboxer)            12
# ...                                                ...
#                 Talk:100% Ver.                       1
#                 Talk:G.O (singer)                    1
#                 Talk:Heo Ga-yoon                     1
#                 Produce 101                          1
#                 Seungho                              1
#
# [136 rows x 1 columns]

# %%
articles = [article_name for (user, article_name) in tmp.index]
articles
# Out:
# ['Speed (South Korean band)',
#  'Asian Television Awards',
#  'BTS',
#  'Gene Shinozaki',
#  'Draft:Bigman (beatboxer)',
#  'Superior Speed',
#  'Mir (singer)',
#  'Speed Circus',
#  'MBLAQ',
#  'Rocket Girls 101',
#  'Thunder (singer)',
#  'List of South Korean idol groups (2010s)',
#  'Reeps One',
#  '100% Ver.',
#  'Produce X 101',
#  'Bigman (beatboxer)',
#  'List of Produce 101 (Chinese TV series) contestants',
#  'Speed of Light (Speed song)',
#  'High School Rapper',
#  'MBK Entertainment',
#  'FNC Entertainment',
#  'Park Sung-hoon (singer)',
#  'Lee Joon',
#  'Seung Ho',
#  'Template:MBK Entertainment',
#  'U-KISS',
#  "The King's Avatar (2019 TV series)",
#  'Grand Beatbox Battle',
#  'Beatbox House',
#  'User talk:Lullabying',
#  'Arthdal Chronicles',
#  'High School Rapper (season 1)',
#  'User talk:Hinorisakamachi',
#  'JYP Entertainment',
#  'Template:Produce 101',
#  'Nguyen Cuong',
#  'Big Hit Entertainment',
#  'Play the Siren',
#  'R1SE',
#  'Stone Music Entertainment',
#  'Oui Entertainment',
#  'Sunye',
#  'Weird Genius',
#  'Kwon So-hyun',
#  'Kim Yo-han (singer)',
#  'Jung Chan-woo (singer)',
#  'JO1 (band)',
#  'List of beatboxers',
#  'Hyuna',
#  '8D Creative',
#  'Berywam',
#  'YG Entertainment',
#  'Shlomo (beatboxer)',
#  'Son Ji-hyun',
#  'Enhypen (band)',
#  'Heo Ga-yoon',
#  'Draft:Weird Genius',
#  'List of Produce X 101 contestants',
#  'Template:Co-Ed School',
#  'Produce 101 (Chinese TV series)',
#  'Big man',
#  'I.O.I',
#  'Kaila Mullady',
#  'Wanna One',
#  'Idol School (2014 TV series)',
#  'K. I. M.',
#  'BLAQ Memories',
#  'Template:CJ E&M Music and Live',
#  'Draft:OUI Entertainment',
#  'Template:MBLAQ',
#  'Beardyman',
#  'Template:SM Entertainment',
#  'X1 (band)',
#  'Sexy, Free & Single',
#  'Exo (group)',
#  'File:BlowSPEEDRepackagealbum.jpg',
#  'File:Lookatmenowrepackage.jpg',
#  'Produce 101 (season 2)',
#  'JO1',
#  'Ha Seok-jin',
#  'Jeon Ji-yoon',
#  'Go Eun-ah',
#  'List of High School Rapper contestants',
#  'File:Superiorspeedregular.jpg',
#  'G.O (singer)',
#  'OnlyOneOf',
#  'Kwon Hyun-bin',
#  'Kim Dong-han',
#  'Template:FNC Entertainment',
#  'Lee Sunmi',
#  'Template:JYP Entertainment',
#  'File:Speedcircuscover.jpg',
#  'Hye-Rim',
#  'Template:Big Hit Entertainment',
#  'Talk:Yang Seung-ho',
#  'Talk:Shlomo (beatboxing artist)',
#  'Talk:Shlomo (beatboxer)',
#  'List of South Korean idol groups (2000s)',
#  'The Ellen DeGeneres Show (season 15)',
#  'Kim Yu-bin (musician)',
#  'Talk:Nguyen Cuong',
#  'Beatbox Battle World Championship',
#  'IKon',
#  'Baljunso',
#  'Ahn So-hee',
#  'User talk:Skier Dude',
#  'Jung Byung Hee',
#  'We Must Love',
#  'Ji Chang-wook',
#  'Talk:Nguyễn Cường',
#  'Talk:Hyuna',
#  'Talk:Kwon So-hyun',
#  'Moranbong Band',
#  'Park Ye-eun',
#  'File:Speedoflight.jpg',
#  'Produce 101 Japan',
#  'File:Lovey-doveyplus.jpg',
#  'File:Catch Me (TVXQ Album).jpg',
#  'SM Entertainment',
#  'Schoolgirl Detectives',
#  'Seol In-ah',
#  'Nguyễn Cường',
#  'Iz*One',
#  'Shlomo (beatboxing artist)',
#  'Talk:Jeon Ji-yoon',
#  '2014 in South Korean music',
#  'Draft:P Nation',
#  'Hommage to Lovey-Dovey',
#  'Chanwoo',
#  'Catch Me (album)',
#  'Supernova (South Korean band)',
#  'Talk:100% Ver.',
#  'Talk:G.O (singer)',
#  'Talk:Heo Ga-yoon',
#  'Produce 101',
#  'Seungho']

# %% [markdown]
# ### Determine if page is kpop related or not

# %%
def find_related(article_name, n):
    '''
    Given an article name, 
    returns n most related articles
    '''
    articles = []
    articles.append(article_name)
    results = wikipedia.search(article_name, results = n)
    articles += results
#     for res in results:
#         articles += wikipedia.search(res, results = int(n/100))
    return articles

# %%
kpop_related = find_related("K-pop", n=500)
bts_related = find_related("BTS", n=500)
related = kpop_related + bts_related

# %%
related[:5]
# Out:
# ['K-pop', 'K-pop', 'List of male K-pop artists', 'K-pop Star', 'Simply K-Pop']

# %%
[x for x in articles if x in related]
# Out:
# ['BTS',
#  'FNC Entertainment',
#  'Lee Joon',
#  'U-KISS',
#  'JYP Entertainment',
#  'Big Hit Entertainment',
#  'Hyuna',
#  'YG Entertainment',
#  'Wanna One',
#  'X1 (band)',
#  'Exo (group)',
#  'List of South Korean idol groups (2000s)',
#  'Kim Yu-bin (musician)',
#  'IKon',
#  'SM Entertainment',
#  'Iz*One',
#  'Produce 101']

# %%
def kpop_fan(user, df):
    '''
    Given a username and dataframe of user contributions,
    determines whether a user is a kpop fan or not
    '''
    u = df[df.users == user].groupby(['users', 'article_name']).count()
    tmp = u.sort_values(by='total_edits', ascending = False)
    #get articles that they contributed in
    total_articles = [article_name for (user, article_name) in tmp.index]
    articles = [x for x in total_articles if x in related]
    #get percentage of kpop contributions
    if len(articles) / len(total_articles) > 0.1:
        return 1
    else:
        return 0

# %%
#given article, determine if users are kpop fans or not
article_name = 'BTS'
fp = "../data/raw/light_dump/Kpop_ld.txt"

#transform data into dataframe format
data = user_contributions(fp, article_name)
df = build_df(data)

#get all related article titles
kpop_related = find_related("K-pop", n=500)
bts_related = find_related("BTS", n=500)
related = kpop_related + bts_related

#analyze each user
unique_users = df.users.unique()
fans = [user for user in unique_users if kpop_fan(user,df) == 1 ]
df['fan'] = df.users.apply(lambda x: 1 if x in fans else 0)

#get percentage of fans
print(len(fans) / len(unique_users))
# Out:
# WARNING: API error baduser: Invalid value "N/A" for user parameter "ucuser".
# 0.8340336134453782

# %%
def percentage_fans(fp, article_name, search_related):
    '''
    Given an article revision history,
    gets percentage of fans from its users.
    '''
    #transform data into dataframe format
    data = user_contributions(fp, article_name)
    df = build_df(data)

    #get all related article titles
    related = []
    for query in search_related:
        related += find_related(query, n=500)

    #analyze each user
    unique_users = df.users.unique()
    fans = [user for user in unique_users if kpop_fan(user,df) == 1 ]
    df['fan'] = df.users.apply(lambda x: 1 if x in fans else 0)

    #get percentage of fans
    return len(fans) / len(unique_users)

# %%
article_name = 'BTS'
fp = "../data/raw/light_dump/Kpop_ld.txt"
search_related = ['K-pop', 'BTS']

percentage_fans(fp, article_name, search_related)
# Out:
# WARNING: API error baduser: Invalid value "N/A" for user parameter "ucuser".
# 0.8340336134453782

# %% [markdown]
# ## updated alg

# %%
article_name = 'BTS'

# %%
import requests

S = requests.Session()

URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "query",
    "format": "json",
    "prop": "categories",
    "titles": article_name
}

R = S.get(url=URL, params=PARAMS)
DATA = R.json()

PAGES = DATA["query"]["pages"]

for k, v in PAGES.items():
    for cat in v['categories']:
        print(cat["title"])
# Out:
# Category:2013 establishments in South Korea
# Category:All Wikipedia articles written in American English
# Category:All articles containing potentially dated statements
# Category:All articles with unsourced statements
# Category:Articles containing Japanese-language text
# Category:Articles containing Korean-language text
# Category:Articles containing potentially dated statements from 2019
# Category:Articles containing potentially dated statements from 2020
# Category:Articles containing potentially dated statements from June 2019
# Category:Articles containing video clips

# %%
S = requests.Session()

URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "query",
    "cmtitle": "Category:K-pop",
    "cmtype": "subcat",
    "list": "categorymembers",
    "format": "json"
}

R = S.get(url=URL, params=PARAMS)
DATA = R.json()

PAGES = DATA["query"]["categorymembers"]

for page in PAGES:
    print(page["title"])
# Out:
# Category:K-pop albums
# Category:K-pop concerts
# Category:K-pop festivals
# Category:K-pop films
# Category:K-pop musicians
# Category:K-pop songs
# Category:K-pop television series
# Category:K-pop websites
